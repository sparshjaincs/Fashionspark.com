# %%
import requests
import re
url="https://myntra.com"
page=requests.get(url)

# %%
page.status_code
# Out:
# 200

# %%
page.headers['Content-type']
# Out:
# 'text/html; charset=utf-8'

# %%
pat1=r"https:?://.*?jpe?g"
x=re.findall(pat1,page.text)
x
# Out:
# ['https://myntra.com/growth/donate-items","loyaltypoints.maxPercentOfCart":"10","loyaltypoints.conversionFactor":1,"loyaltypoints.enable":false,"mymyntra.phonepe.enable":"false","checkout.codCaptcha.enable":true,"checkout.codOtp.enable":true,"mymyntra.ratings.enable":true,"pdp.crossSell.enable":"true","list.imageSlider.enable":"true","pdp.mfa.recommendation.enable":"true","mymyntra.ifscvalidation.enable":true,"checkout.cart.filler":true,"search.enableSortDeliveryTime":"true","payments.autoSaveCard.enabled":false,"slots.fetchSlot":false,"slots.assignSlotATW":false,"slots.context":"general","slots.refreshRate":300,"checkout.twofaauth.enabled":true,"web.ratings.enable":true,"mymyntra.reviewPhotos.enable":true,"mymyntra.returnTracking.enabled":false,"mymyntra.refundBreakup.enabled":false};window["__myx_kvpairs__"]={"header.promotion.data":"{\\r\\n    \\"code\\": \\"App only\\",\\r\\n    \\"text\\": \\"Get 20% Off* on orders above Rs.1599 only on App | Download Now\\",\\r\\n    \\"link\\"
# ...

# %%
x[:25]
# Out:
# ['https://myntra.com/growth/donate-items","loyaltypoints.maxPercentOfCart":"10","loyaltypoints.conversionFactor":1,"loyaltypoints.enable":false,"mymyntra.phonepe.enable":"false","checkout.codCaptcha.enable":true,"checkout.codOtp.enable":true,"mymyntra.ratings.enable":true,"pdp.crossSell.enable":"true","list.imageSlider.enable":"true","pdp.mfa.recommendation.enable":"true","mymyntra.ifscvalidation.enable":true,"checkout.cart.filler":true,"search.enableSortDeliveryTime":"true","payments.autoSaveCard.enabled":false,"slots.fetchSlot":false,"slots.assignSlotATW":false,"slots.context":"general","slots.refreshRate":300,"checkout.twofaauth.enabled":true,"web.ratings.enable":true,"mymyntra.reviewPhotos.enable":true,"mymyntra.returnTracking.enabled":false,"mymyntra.refundBreakup.enabled":false};window["__myx_kvpairs__"]={"header.promotion.data":"{\\r\\n    \\"code\\": \\"App only\\",\\r\\n    \\"text\\": \\"Get 20% Off* on orders above Rs.1599 only on App | Download Now\\",\\r\\n    \\"link\\"
# ...
